# %%
# %pip install -Uq ultralytics hub-sdk
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.7/699.7 kB 5.8 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
# !curl -o FRC2024.zip 'https://api.datasetcolab.com/download/FRC2024?api=aUnr1hUqnKanmieKtFWS1RSi&datasetType=YOLO&classes=NO'

# !unzip FRC2024.zip

# %% [markdown]
# Add the line `  1: background` to `data.yaml`, as some of the data has an extra category

# %% [markdown]
# A full list of training arguments can be found [here](https://docs.ultralytics.com/modes/train/#arguments)

# %%
model_name = "yolov8n.pt"

# Auto batch
metrics = YOLO(model_name).train(model = model_name, data = "data.yaml", epochs = 4, batch = 64)
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Validate the model

metrics = model.val()
